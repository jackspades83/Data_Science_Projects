# %% [markdown]
# # <center> <font color=#B40404>Recommendation Systems Project</center>
#
# ## <center> <font color=#B40404>Submitted by Utathya Ghosh</center>
#
# ### <center> <font color=#B40404>Batch - AIML Online Jan 21-A</center>

# %% [markdown]
# # <center>PROJECT BASED</center>
# # <center>TOTAL SCORE - 60</center>

# %% [markdown]
# DOMAIN: Smartphone, Electronics
#
# CONTEXT: India is the second largest market globally for smartphones after China. About 134 million smartphones were sold across India
# in the year 2017 and is estimated to increase to about 442 million in 2022. India ranked second in the average time spent on mobile web by
# smartphone users across Asia Pacific. The combination of very high sales volumes and the average smartphone consumer behaviour has
# made India a very attractive market for foreign vendors. As per Consumer behaviour, 97% of consumers turn to a search engine when they
# are buying a product vs. 15% who turn to social media. If a seller succeeds to publish smartphones based on user’s behaviour/choice at the
# right place, there are 90% chances that user will enquire for the same. This Case Study is targeted to build a recommendation system
# based on individual consumer’s behaviour or choice.
#
# DATA DESCRIPTION:
#
#     • author : name of the person who gave the rating
#     • country : country the person who gave the rating belongs to
#     • data : date of the rating
#     • domain: website from which the rating was taken from
#     • extract: rating content
#     • language: language in which the rating was given
#     • product: name of the product/mobile phone for which the rating was given
#     • score: average rating for the phone
#     • score_max: highest rating given for the phone
#     • source: source from where the rating was taken
#     *Data source:
#
# PROJECT OBJECTIVE: We will build a recommendation system using popularity based and collaborative filtering methods to recommend
# mobile phones to a user which are most popular and personalised respectively.

# %% [markdown]
# Steps and tasks: [ Total Score: 60 points]

# %%
# Load required packages
import pandas as pd
import numpy as np
import os
from surprise import Dataset
from surprise import Reader
from surprise import SVD
from surprise import KNNWithMeans
from surprise import accuracy
from collections import defaultdict
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# %% [markdown]
# #### 1. Import the necessary libraries and read the provided CSVs as a data frame and perform the below steps.
# ###### • Merge the provided CSVs into one data-frame.#

# %%
# Function to extract names of all files from OS
def find_csv_filenames(path_to_dir, suffix=".csv" ):
    filenames = os.listdir(path_to_dir)
    return([filename for filename in filenames if filename.endswith( suffix )])

# %%
# Load all files and join them into one dataframe
df_master = pd.DataFrame()
for f in find_csv_filenames(os.path.abspath('')):
    df_master = pd.concat([df_master, pd.read_csv(f)])
    
# Reset index of the combined dataframe
df_master.reset_index(drop=True, inplace=True)

# Display combined dataframe basic information
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1415133 entries, 0 to 1415132
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 118.8+ MB

# %% [markdown]
# ###### • Check a few observations and shape of the data-frame.

# %%
# View random records
df_master.sample(30)
# Out:
#                                        phone_url        date lang country  \
# 291533        /cellphones/samsung-galaxy-note-4/  12/11/2014   es      es
# 1115835    /cellphones/sony-ericsson-xperia-x10/   2/19/2011   ru      ru
# 425363          /cellphones/lenovo-vibe-k4-note/    4/5/2016   en      in
# 871490   /cellphones/sony-ericsson-xperia-neo-v/  28/11/2012   ru      ru
# 966370               /cellphones/nokia-asha-300/   6/15/2012   fr      fr
# 495842                 /cellphones/wiko-rainbow/   9/17/2016   it      it
# 1093444                    /cellphones/nokia-c5/  12/31/2011   ru      ru
# 259747               /cellphones/elephone-p8000/   9/11/2015   de      de
# 882344              /cellphones/apple-iphone-4s/   17/1/2012   en      gb
# 1170019               /cellphones/samsung-e1360/  10/13/2009   ru      ru
# 709213               /cellphones/alcatel-idol-x/   4/16/2014   ru      ru
# 311666           /cellphones/asus-zenfone-3-max/  12/15/2016   ru      ru
# 551236               /cellphones/htc-desire-628/    7/9/2016   en      in
# 250878                  /cellphones/htc-one-m8s/    1/5/2016   it      it
# 769526       /cellphones/motorola-droid-razr-hd/   6/15/2013   fr      fr
# 69431                 /cellphones/huawei-mate-9/   4/28/2017   en      us
# 554939           /cellphones/blackberry-classic/  10/21/2015   de      de
# 357172      /cellphones/samsung-galaxy-j7-prime/   12/2/2016   en      us
# 489355             /cellphones/acer-liquid-m330/    3/2/2017   en      us
# 170555              /cellphones/huawei-honor-4x/   4/29/2015   en      gb
# 509984               /cellphones/lenovo-vibe-k5/   7/25/2016   en      in
# 1073817            /cellphones/apple-iphone-3gs/   2/19/2010   sv      se
# 378032              /cellphones/nokia-lumia-630/   4/14/2015   de      de
# 327515              /cellphones/motorola-moto-g/  12/16/2016   it      it
# 684852                /cellphones/sony-xperia-l/    1/1/2015   de      de
# 142123         /cellphones/motorola-moto-z-play/   2/11/2016   it      it
# 585514                   /cellphones/lg-g3-d722/   3/10/2015   ru      ru
# 1268098          /cellphones/nokia-3110-classic/   4/22/2013   ru      ru
# 518960               /cellphones/zte-blade-a452/   1/27/2017   de      de
# 611491                     /cellphones/cubot-x6/    3/7/2015   it      it
#
#                  source              domain  score  score_max  \
# 291533           Amazon           amazon.es   10.0       10.0
# 1115835          Yandex    market.yandex.ru    2.0       10.0
# 425363           Amazon           amazon.in   10.0       10.0
# 871490           Yandex    market.yandex.ru   10.0       10.0
# 966370           Amazon           amazon.fr    8.0       10.0
# 495842           Amazon           amazon.it    6.0       10.0
# 1093444          Yandex    market.yandex.ru    8.0       10.0
# 259747           Amazon           amazon.de   10.0       10.0
# 882344           Amazon        amazon.co.uk   10.0       10.0
# 1170019          Yandex    market.yandex.ru   10.0       10.0
# 709213       Irecommend       irecommend.ru    8.0       10.0
# 311666          Связной         svyaznoy.ru    NaN        NaN
# 551236        Smartprix       smartprix.com    8.0       10.0
# 250878           Amazon           amazon.it   10.0       10.0
# 769526              SFR         avis.sfr.fr    NaN        NaN
# 69431         B&H Photo    bhphotovideo.com   10.0       10.0
# 554939           Amazon           amazon.de   10.0       10.0
# 357172           Amazon          amazon.com    6.0       10.0
# 489355   MicrosoftStore  microsoftstore.com    8.0       10.0
# 170555           Amazon        amazon.co.uk   10.0       10.0
# 509984           Amazon           amazon.in    8.0       10.0
# 1073817        Prisjakt         prisjakt.nu   10.0       10.0
# 378032           Amazon           amazon.de    2.0       10.0
# 327515           Amazon           amazon.it    8.0       10.0
# 684852           Amazon           amazon.de    8.0       10.0
# 142123             Ciao             ciao.it   10.0       10.0
# 585514       Irecommend       irecommend.ru   10.0       10.0
# 1268098          Yandex    market.yandex.ru   10.0       10.0
# 518960          Otto.de             otto.de   10.0       10.0
# 611491           Amazon           amazon.it    8.0       10.0
#
#                                                    extract  \
# 291533   Llevo bastante tiempo utilizando productos de ...
# 1115835                                  Всем доброго дня!
# 425363             Very good phone in this price I love it
# 871490   ??????.??????????????, ?????????�???? ???? ???...
# 966370   tactile pas terrible pas de reglage sensibilit...
# 495842   Mi ha accompagnato per un anno e mezzo ed ha s...
# 1093444  в целом телефоном отличный очень доволен покуп...
# 259747   Das Handy ist eine sehr gute Wahl und wir könn...
# 882344              really pleased with the phone - thanks
# 1170019  В общем, для своей цены - совершенно замечател...
# 709213   Давно полюбила эту марку телефонов.Хорошие пар...
# 311666                        Минусов только 2 читать выше
# 551236           Its has a brand name with grt featurs too
# 327515   Lenovo Motorola Moto G 4G (2 Generazione) Smar...
# 684852   Sony Xperia L Smartphone (10,9 cm (4,3 Zoll) T...
# 142123                          Motorola Moto Z Play 32 GB
# 585514   Мобильные телефоны Мобильный телефон LG G3 s D724
# 1268098                                 Nokia 3110 Classic
# 518960   ZTE Blade A452 Smartphone, 12,7 cm (5 Zoll) Di...
# 611491   Cubot X6 - OCTA CORE SMARTPHONE DUAL SIM TELEF...

# %%
# Display the shape and size
print("Shape of Master dataset: ", df_master.shape)
print("Size of Master dataset: ", df_master.size)
# Out:
# Shape of Master dataset:  (1415133, 11)
# Size of Master dataset:  15566463

# %% [markdown]
# ###### • Round off scores to the nearest integers.

# %%
# View unique values to gauge the format
print(np.unique(df_master["score"]))
print(np.unique(df_master["score_max"]))
# Out:
# [0.2 0.4 0.6 ... nan nan nan]
# [10. nan nan ... nan nan nan]

# %% [markdown]
# ###### <font color=#B40404>Score column has multiple null values. Since this is an important column for further calculation if we impute the null values we risk adding bias and error to the models we will build ahead. Hence instead of imputing null values of 'score' we will drop them and impute the null values of 'score max' to 0.

# %%
# Dropping Null values in score
df_master.dropna(axis=0, subset=['score'], inplace=True)

# %%
# Achieving round of by converting float to int32
df_master["score_max"] = np.around(df_master["score_max"].replace({np.nan: 0})).astype("int32")
df_master["score"] = np.around(df_master["score"]).astype("int32")
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1351644 entries, 0 to 1415132
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1351644 non-null  object
#  1   date       1351644 non-null  object
#  2   lang       1351644 non-null  object
#  3   country    1351644 non-null  object
#  4   source     1351644 non-null  object
#  5   domain     1351644 non-null  object
#  6   score      1351644 non-null  int32
#  7   score_max  1351644 non-null  int32
#  8   extract    1332699 non-null  object
#  9   author     1291038 non-null  object
#  10  product    1351643 non-null  object
# dtypes: int32(2), object(9)
# memory usage: 113.4+ MB

# %% [markdown]
# ###### • Check for missing values. Impute the missing values if there is any.

# %% [markdown]
# ###### <font color=#B40404>We have already noted that there are a lot of null values. However, the null values in 'author' and 'product' column is quite troublesome. Going forward these two columns will become our user and item list, to not have values here may result in biases and errors. Hence we will drop all the records with null values in 'author' and 'product'. Any other column with null values we will impute.

# %%
# Dropping records with null values in author and product
df_master.dropna(axis=0, subset=['author', 'product'], inplace=True)

# Imputing remaining null values to ' '
df_master = df_master.replace({np.nan: ' '})

# Viewing basic information of dataframe
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291038 entries, 0 to 1415132
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1291038 non-null  object
#  1   date       1291038 non-null  object
#  2   lang       1291038 non-null  object
#  3   country    1291038 non-null  object
#  4   source     1291038 non-null  object
#  5   domain     1291038 non-null  object
#  6   score      1291038 non-null  int32
#  7   score_max  1291038 non-null  int32
#  8   extract    1291038 non-null  object
#  9   author     1291038 non-null  object
#  10  product    1291038 non-null  object
# dtypes: int32(2), object(9)
# memory usage: 108.3+ MB

# %% [markdown]
# ###### • Check for duplicate values and remove them if there is any.

# %%
# Remove Duplicate values
df_master = df_master.loc[~df_master.duplicated(keep = 'first')]

# Display basic information
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1286361 entries, 0 to 1415132
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1286361 non-null  object
#  1   date       1286361 non-null  object
#  2   lang       1286361 non-null  object
#  3   country    1286361 non-null  object
#  4   source     1286361 non-null  object
#  5   domain     1286361 non-null  object
#  6   score      1286361 non-null  int32
#  7   score_max  1286361 non-null  int32
#  8   extract    1286361 non-null  object
#  9   author     1286361 non-null  object
#  10  product    1286361 non-null  object
# dtypes: int32(2), object(9)
# memory usage: 108.0+ MB

# %% [markdown]
# ###### • Keep only 1000000 data samples. Use random state=612.

# %%
# Keep only 1000000 records
df_tel = df_master.sample(1000000, random_state=612).copy().reset_index(drop=True)

# %% [markdown]
# ###### • Drop irrelevant features. Keep features like Author, Product, and Score.

# %% [markdown]
# ###### <font color=#B40404>We drop all features except for: -
# - "Author"  --- Changed to 'user'
# - "Product" --- Changed to 'item'
# - "Score"   --- Changed to 'rating'
# - "country" --- We will keep this for the time being for a particular purpose, post which it will be promptly dropped

# %%
# Keeping only relevant columns
df_tel = df_tel[["country", "author", "product", "score"]].copy()

# Renaming columns to more meaningful names
df_tel.columns = ["country", "user", "item", "rating"]

# Display dataframe
df_tel.head()
# Out:
#   country            user                                               item  \
# 0      ar  VIRTUALKIO2008                                           LG MG220
# 1      it  Piero Montagno  Nokia 130 Telefono Cellulare, Display da 1.8",...
# 2      us      itsthemom                    Samsung Galaxy S7 32GB (Verizon)
# 3      in     Nisar Ahmed                        OnePlus 3 (Graphite, 64 GB)
# 4      gb   Milosav Pesic  Nokia Sony Ericsson C510 Black Mobile Phone Si...
#
#    rating
# 0       8
# 1       6
# 2       6
# 3       8
# 4      10

# %% [markdown]
# ###### <font color=#B40404>Before proceeding further we will also remove all leading and trailing white spaces from 'user' and 'item' columns and convert all users to lower case

# %%
# Stripping leading and trailing whitespaces
df_tel['user'] = df_tel['user'].str.strip().str.lower()
df_tel['item'] = df_tel['item'].str.strip()

# Viewing dataframe
df_tel
# Out:
#        country            user  \
# 0           ar  virtualkio2008
# 1           it  piero montagno
# 2           us       itsthemom
# 3           in     nisar ahmed
# 4           gb   milosav pesic
# ...        ...             ...
# 999995      us           aaron
# 999996      gb             uhn
# 999997      us          grigor
# 999998      de    einer kundin
# 999999      de        wolfgang
#
#                                                      item  rating
# 0                                                LG MG220       8
# 1       Nokia 130 Telefono Cellulare, Display da 1.8",...       6
# 2                        Samsung Galaxy S7 32GB (Verizon)       6
# 3                             OnePlus 3 (Graphite, 64 GB)       8
# 4       Nokia Sony Ericsson C510 Black Mobile Phone Si...      10
# ...                                                   ...     ...
# 999995           Casio G'zOne Ravine 2 C781 Verizon Black      10
# 999996        HTC 10 Sim Free Smartphone - Glacier Silver      10
# 999997  BLU Vivo XL Smartphone - 5.5" 4G LTE - GSM Unl...      10
# 999998  Huawei P9 Lite Dual-SIM Smartphone, 13,2 cm (5...      10
# 999999  Apple iPhone 6 Space Grau 128GB SIM-Free Smart...       8
#
# [1000000 rows x 4 columns]

# %% [markdown]
# #### 2. Answer the following questions
# ###### • Identify the most rated features.

# %%
# Display the most rated items
df_tel.groupby("item").count().sort_values("user", ascending=False)
# Out:
#                                                     country  user  rating
# item
# Lenovo Vibe K4 Note (White,16GB)                       4030  4030    4030
# Lenovo Vibe K4 Note (Black, 16GB)                      3405  3405    3405
# OnePlus 3 (Graphite, 64 GB)                            3187  3187    3187
# OnePlus 3 (Soft Gold, 64 GB)                           2746  2746    2746
# Huawei P8lite zwart / 16 GB                            2104  2104    2104
# ...                                                     ...   ...     ...
# Nokia E6-00 Zwart                                         1     1       1
# Nokia E6-00 - Móvil libre (pantalla táctil de 2...        1     1       1
# Nokia E6 Sim Free Mobile Phone - White                    1     1       1
# Nokia E6 Sim Free Mobile Phone - Silver                   1     1       1
# 摩托罗拉 C168i                                                1     1       1
#
# [52245 rows x 3 columns]

# %% [markdown]
# ###### • Identify the users with most number of reviews.

# %%
df_tel.groupby("user").count().sort_values("item", ascending=False)
# Out:
#                  country   item  rating
# user
# amazon customer    59929  59929   59929
# cliente amazon     14947  14947   14947
# e-bit               6609   6609    6609
# client d'amazon     5976   5976    5976
# amazon kunde        3690   3690    3690
# ...                  ...    ...     ...
# henry g.               1      1       1
# henry fuentes          1      1       1
# henry franz            1      1       1
# henry f.               1      1       1
# �¬‰¢                   1      1       1
#
# [603102 rows x 3 columns]

# %% [markdown]
# ###### • Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the final dataset.

# %%
# Build a new dataframe with users and item with more than 50 ratings
df_tel50 = df_tel[df_tel.groupby("user")["item"].transform('count')>50].copy()
df_tel50 = df_tel50[df_tel50.groupby("item")["user"].transform('count')>50].copy()

# Display shape of new dataframe
df_tel50.shape
# Out:
# (68452, 4)

# %% [markdown]
# #### 3. Build a popularity based model and recommend top 5 mobile phones.

# %%
# Display top 5 mobile phones by rating in the world
print("Top 5 mobile phones in the world are :")
print(list(df_tel50.groupby("item").mean().sort_values("rating", ascending=False).head(5).index))

# Display top 5 mobile phones by rating by country
for cntry in np.unique(df_tel50["country"]):
    print("\nTop 5 mobile phones in ", cntry, " are :")
    print(list(
        df_tel50[df_tel50["country"] == cntry].groupby("item").mean().sort_values("rating", ascending=False).head(5).index))
    
# Drop country column as it has no more use
df_tel50.drop("country", axis=1, inplace=True)
# Out:
# Top 5 mobile phones in the world are :
# ['Samsung Galaxy Note5', 'Apple iPhone 7 4,7" 32 GB', 'Apple iPhone 6s 4,7" 128 GB', 'Smartphone Asus ZenFone 3 ZE552KL', 'Samsung Galaxy S7 32GB (T-Mobile)']
#
# Top 5 mobile phones in  au  are :
# ['Motorola Moto G 3rd Gen - Black']
#
# Top 5 mobile phones in  be  are :
# ['Samsung Galaxy S7 Edge wit / 32 GB', 'Samsung Galaxy S7 zwart / 32 GB', 'Samsung Galaxy S7 Edge zwart / 32 GB', 'Huawei P8 Lite wit / 16 GB', 'Samsung Galaxy S7 Edge goud / 32 GB']
#
# Top 5 mobile phones in  br  are :
# ['Smartphone Asus ZenFone 3 ZE552KL', 'Smartphone LG G2 D805', 'Smartphone Motorola Moto Z Play XT1635', 'Smartphone Samsung Galaxy S7 SM-G930 32GB', 'Smartphone Apple iPhone 6 16GB']
#
# Top 5 mobile phones in  ca  are :
# ['Lumia Microsoft Nokia Lumia 640 RM-1073 Unlocked Phone (Black)', 'Samsung Galaxy Note 3/S5 USB 3.0 5-Feet Data Cable, Non-Retail Packaging']
#
# Top 5 mobile phones in  de  are :
# ['Apple iPhone 7 4,7" 32 GB', 'Apple iPhone 6s 4,7" 128 GB', 'Apple iPhone 6s Plus 5,5" 128 GB', 'Huawei P9 Lite Dual-SIM Smartphone, 13,2 cm (5,2 Zoll) Display, LTE (4G), Android 6.0 (Marshmallow)', 'Samsung Galaxy S7 edge Smartphone, 13,9 cm (5,5 Zoll) Display, LTE (4G)']
#
# Top 5 mobile phones in  es  are :
# ['LG G2 - Smartphone libre Android (pantalla 5.2", cámara 13 Mp, 16 GB, Quad-Core 2.3 GHz, 2 GB RAM), blanco', 'Honor 6 - Smartphone libre (pantalla de 5", 16GB, 3 GB de RAM, cámara trasera de 13 MP y delantera de 5 MP, Android OS, v4.4.2 KitKat, LTE) blanco', "Lenovo Motorola Moto G4 - Smartphone libre Android 6 (pantalla de 5.5'' Full HD, 4G, cámara de 13 MP, 2 GB de RAM, 16 GB, Qualcomm Snapdragon 1.5 GHz), color negro", 'Samsung Galaxy S7 SM-G930F 32GB 4G - Smartphone (SIM única, Android, NanoSIM, GSM, HSPA+, LTE), Rosa', 'LG Nexus 5X - Smartphone libre Android (pantalla 5.2", cámara 12.3 MP, 2 GB de RAM, 16 GB), color negro']
#
# Top 5 mobile phones in  fr  are :
# ['Samsung Galaxy S6', 'HTC Desire', 'Honor 8 Smartphone débloqué 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc Nacré', 'Honor 7 Smartphone débloqué 4G (Ecran: 5,2 pouces - 16 Go - Double Nano SIM - Android 5.0 Lollipop) Argent/Blanc', 'AICEK Coque Samsung Galaxy A3 2016, AICEK Etui Silicone Gel Samsung Galaxy A3 2016 (A310F) Housse Antichoc Samsung A3 Transparente Souple Coque De Protection Pour Samsung Galaxy A3 2016 (4,7 pouces)']
#
# Top 5 mobile phones in  gb  are :
# ['Samsung Galaxy A3', 'Samsung Galaxy S6', 'APPLE iPhone 6s Plus - 128 GB, Rose Gold', 'Sim Free Motorola Moto G 4th Generation Mobile Phone - Black', 'Motorola Moto G 3rd Generation LTE UK SIM-Free Smartphone - White']
#
# Top 5 mobile phones in  in  are :
# ['Samsung Galaxy S7', 'Samsung Galaxy J3 (8GB)', 'OnePlus 3 (Graphite, 64 GB)', 'OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)', 'OnePlus 3 (Soft Gold, 64 GB)']
#
# Top 5 mobile phones in  it  are :
# ['Lenovo Motorola Moto G Smartphone, Display HD 4,5", Processore Qualcomm, Memoria 8 GB, MicroSIM, Android 4.4 OS, Fotocamera da 5 MP, Nero [Germania]', 'LG D802 G2 Smartphone, 16 GB, Nero [Italia]', 'Asus ZenFone 3 Smartphone, Memoria Interna da 64 GB, Dual-SIM, Bianco [Italia]', 'Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', 'LG Nexus 5 Smartphone, memoria 16GB, Android 4.4, Nero [Italia]']
#
# Top 5 mobile phones in  nl  are :
# ['Samsung Galaxy A5', 'Samsung Galaxy S7 edge', 'Samsung Galaxy A5 (2016)', 'Apple Apple iPhone 6s - 128GB - Zwart', 'Samsung Samsung Galaxy A5 2016 - Wit']
#
# Top 5 mobile phones in  pl  are :
# ['Samsung Galaxy A3 (2016)', 'Samsung Galaxy A5 (2016)', 'Samsung Galaxy J3 (2016)', 'Samsung Galaxy S6', 'Samsung Galaxy S7 edge']
#
# Top 5 mobile phones in  ru  are :
# ['Samsung Galaxy A5 (2016)', 'Samsung Galaxy Note5', 'Samsung Galaxy S7', 'Samsung Galaxy A5', 'Samsung Galaxy S7 edge']
#
# Top 5 mobile phones in  tr  are :
# ['Samsung Galaxy A3 (2016)']
#
# Top 5 mobile phones in  ua  are :
# ['HTC Desire', 'Samsung Galaxy S6', 'LG Optimus L7 P705 Black', 'HTC Desire SV T326e Black 4710937389005 UACRF', 'Nokia 101 Premium Black']
#
# Top 5 mobile phones in  us  are :
# ['Samsung Galaxy S7 edge', 'Samsung Galaxy S7 32GB (T-Mobile)', 'Samsung Galaxy S7 edge 32GB (T-Mobile)', 'Samsung Galaxy S7 edge 32GB (Verizon)', 'LG Dare']

# %% [markdown]
# #### 4. Build a collaborative filtering model using SVD. You can use SVD from surprise or build it from scratch(Note: Incase you’re building it from scratch you can limit your data points to 5000 samples if you face memory issues). Build a collaborative filtering model using kNNWithMeans from surprise. You can try both user-based and item-based model.

# %% [markdown]
# ###### <font color=#B40404>First using SVD from surprise to build a collaborative filtering model.

# %%
# Building a reader
reader = Reader(rating_scale=(0, 10))

# Creating our data from df_tel50 dataframe
data = Dataset.load_from_df(df_tel50[["user", "item", "rating"]], reader)

# Initialising model with SVD from surprise
svd = SVD(verbose=True, n_epochs=10)

# Creating trainset and testset from data
trainset, testset = train_test_split(data, test_size=.2)

# Training model svd
svd.fit(trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9

# %% [markdown]
# ###### <font color=#B40404>Second using kNNWithMeans from surprise to build an user-based collaborative filtering model.

# %%
# Use kNNWithMeans from surprise to build an user-based collaborative filter model
algo_user = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo_user.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ###### <font color=#B40404>Third using kNNWithMeans from surprise to build an item-based collaborative filtering model.

# %%
# Use kNNWithMeans from surprise to build an item-based collaborative filter model
algo_item = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo_item.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# #### 5. Evaluate the collaborative model. Print RMSE value.

# %%
# Get prediction for svd based collaborative filtering model
# run the trained model against the testset
svd_pred = svd.test(testset)

# get RMSE for svd based collaborative filtering model
print("SVD-based Model : Test Set")
accuracy.rmse(svd_pred, verbose=True)

# Get prediction for user-based collaborative filtering model
# run the trained model against the testset
usr_pred = algo_user.test(testset)

# get RMSE for user-based collaborative filtering model
print("\nUser-based Model : Test Set")
accuracy.rmse(usr_pred, verbose=True)

# Get prediction for item-based collaborative filtering model
# run the trained model against the testset
itm_pred = algo_item.test(testset)

# get RMSE for item-based collaborative filtering model
print("\nItem-based Model : Test Set")
accuracy.rmse(itm_pred, verbose=True)
# Out:
# SVD-based Model : Test Set
# RMSE: 2.5794
#
# User-based Model : Test Set
# RMSE: 2.6529
#
# Item-based Model : Test Set
# RMSE: 2.6543
# 2.654309141347851

# %% [markdown]
# #### 6. Predict score (average rating) for test users.

# %% [markdown]
# ###### <font color=#B40404>First using SVD from surprise.

# %%
# Initialise lists for df_svd_score columns
ls_id, ls_score = [], []

# Run through all predictions to extract required values
for idx in range(len(svd_pred)):
    ls_id.append(svd_pred[idx].uid)
    ls_score.append(svd_pred[idx].est)

# Creating dataframe to display score
df_svd_score = pd.DataFrame([ls_id, ls_score], index=["user", "rating"]).T

# Rearranging dataframe to display score
df_svd_score["rating"] = df_svd_score["rating"].astype("float32")

# Displaying scores
print("Score (average rating) for all test users : ", df_svd_score.groupby("user").mean().mean())
print("\nScore (average rating) for individual test users : -")
df_svd_score.groupby("user").mean()
# Out:
# Score (average rating) for all test users :  rating    8.259321
# dtype: float32
#
# Score (average rating) for individual test users : -
#                                rating
# user
# ????????                     8.923452
# ??????????                   8.959071
# ????????????                 9.333807
# ???????????? ????????        8.702247
# ???????????? ??????????????  8.436412
# ...                               ...
# сергей                       8.923686
# татьяна                      8.962490
# юлия                         9.306425
# юрий                         8.854916
# яна                          8.603773
#
# [652 rows x 1 columns]

# %% [markdown]
# ###### <font color=#B40404>Second using user-based kNNWithMeans from surprise.

# %%
# Initialise lists for df_usr_score columns
ls_id, ls_score = [], []

# Run through all predictions to extract required values
for idx in range(len(usr_pred)):
    ls_id.append(usr_pred[idx].uid)
    ls_score.append(usr_pred[idx].est)

# Creating dataframe to display score
df_usr_score = pd.DataFrame([ls_id, ls_score], index=["user", "rating"]).T

# Rearranging dataframe to display score
df_usr_score["rating"] = df_usr_score["rating"].astype("float32")

# Displaying scores
print("Score (average rating) for all test users : ", df_usr_score.groupby("user").mean().mean())
print("\nScore (average rating) for individual test users : -")
df_usr_score.groupby("user").mean()
# Out:
# Score (average rating) for all test users :  rating    8.223465
# dtype: float32
#
# Score (average rating) for individual test users : -
#                                 rating
# user
# ????????                      9.063495
# ??????????                    8.962032
# ????????????                  9.469950
# ???????????? ????????        10.000000
# ???????????? ??????????????   7.859644
# ...                                ...
# сергей                        8.791846
# татьяна                       8.987241
# юлия                          9.399129
# юрий                          9.092880
# яна                           8.852639
#
# [652 rows x 1 columns]

# %% [markdown]
# ###### <font color=#B40404>Second using item-based kNNWithMeans from surprise.

# %%
# Initialise lists for df_itm_score columns
ls_id, ls_score = [], []

# Run through all predictions to extract required values
for idx in range(len(itm_pred)):
    ls_id.append(itm_pred[idx].uid)
    ls_score.append(itm_pred[idx].est)

# Creating dataframe to display score
df_itm_score = pd.DataFrame([ls_id, ls_score], index=["user", "rating"]).T

# Rearranging dataframe to display score
df_itm_score["rating"] = df_itm_score["rating"].astype("float32")

# Displaying scores
print("Score (average rating) for all test users : ", df_itm_score.groupby("user").mean().mean())
print("\nScore (average rating) for individual test users : -")
df_itm_score.groupby("user").mean()
# Out:
# Score (average rating) for all test users :  rating    8.215114
# dtype: float32
#
# Score (average rating) for individual test users : -
#                                 rating
# user
# ????????                      9.097410
# ??????????                    8.967369
# ????????????                  9.461138
# ???????????? ????????        10.000000
# ???????????? ??????????????   7.859644
# ...                                ...
# сергей                        8.854269
# татьяна                       8.960356
# юлия                          9.320087
# юрий                          9.079974
# яна                           8.939413
#
# [652 rows x 1 columns]

# %% [markdown]
# #### 7. Report your findings and inferences.

# %% [markdown]
# ###### <font color=#B40404>Based on the results we got on the accuracy (RMSE) scores. SVD is definitely outperforming kNNWithMeans. We will go ahead and confirm that later with cross validation.
#
# ###### <font color=#B40404>However, all three have an RMSE around 2.5, which in my view is quite high. Although, if this model is going to be used in a scenario where getting the real ratings is not very critical then this model is quick, fast and does an excellent job considering how sparse the initial matrix was. To give the client an idea, about 23K cells out 24K cells were empty when building the matrix factorisation table. So in that respect our model has done well.
#
# ###### <font color=#B40404>Looking at the average rating of the model we can also assume that most people have given very high ratings, this could be a bias of giving a rating only when people are satisfied. Which does not represent true feedback however, again considering that this model will be used to recommend phone to other users, this bias does not play spoilsport.

# %% [markdown]
# #### 8. Try and recommend top 5 products for test users.

# %%
# Function to get top 5 user ratings
def get_top_n(predictions, n=10):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the n highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return(top_n)

# %% [markdown]
# ###### <font color=#B40404>Using SVD from surprise to  recommend 5 products for each user since Collaboration filtering model with SVD from surprise gave the best accuracy.

# %%
# Recommending top 5 products for each user
top_n = get_top_n(svd_pred, n=5)

# Print the recommended items for each user
for uid, user_ratings in top_n.items():
    print('\n', uid, [iid for (iid, _) in user_ratings])
# Out:
#  e-bit ['Smartphone Asus ZenFone 3 ZE552KL', 'Smartphone Asus ZenFone 3 ZE552KL', 'Smartphone Asus ZenFone 3 ZE552KL', 'Smartphone Asus ZenFone 3 ZE552KL', 'Smartphone Asus ZenFone 3 ZE552KL']
#
#  amazon customer ['Motorola Moto G 3rd Generation LTE UK SIM-Free Smartphone - White', 'Motorola Moto G 3rd Generation LTE UK SIM-Free Smartphone - White', 'Motorola Moto G 3rd Generation LTE UK SIM-Free Smartphone - White', 'Motorola Moto G 3rd Generation LTE UK SIM-Free Smartphone - White', 'Motorola Moto G 3rd Generation LTE UK SIM-Free Smartphone -
huawei Honor 5X Unlocked Smartphone, 16GB Dark Grey (US Warranty)', 'Huawei P8 Lite goud, wit / 16 GB']
#
#  gaurav ['Apple iPhone 5s (Silver, 16GB)', 'VIVO V5 (Crown gold, 32 GB) (4 GB RAM)', 'OnePlus 3 (Soft Gold, 64 GB)', 'Motorola Moto G, 4th Gen (Black, 2 GB, 16 GB)', 'Apple iPhone 5s (Gold, 16GB)']
#
#  дмитрий ['Samsung Galaxy Note5', 'Samsung Galaxy A5', 'Apple iPhone 5s 16GB (серый космос)', 'Apple iPhone 5s 16GB (серый космос)', 'Sony Xperia Z1 Compact (черный)']
#
#  sachin ['Samsung Galaxy S7', 'OnePlus 3 (Soft Gold, 64 GB)', 'Motorola Moto G 3rd Generation (White, 16GB)', 'Apple iPhone 6s (Rose Gold, 16GB)', 'Lenovo A2010 4G (Black)']
#
#  mark ['APPLE iPhone 6s Plus - 128 GB, Rose Gold', 'Huawei Honor 5X Unlocked Smartphone, 16GB Dark Grey (US Warranty)', 'Samsung Galaxy S7 zwart / 32 GB', 'Samsung Galaxy S7 zwart / 32 GB', 'Samsung Galaxy S6']
#
#  angelo ['Lenovo Motorola Moto G Smartphone, Display HD 4,5", Processore Qualcomm, Memoria 8 GB, MicroSIM, Android 4.4 OS, Fotocamera da 5 MP, Nero [Germania]', 'Asus ZE551ML-2A760WW Smartphone ZenFone 2 Deluxe, 5.5", 4 GB RAM, 64 GB, Intel Quad-Core Z3580, Dual SIM, Illusion Purple', 'Lenovo Motorola Moto E 2a Generazione Smartphone, LTE, 8 GB, RAM 1 GB, Nero [Italia]', 'Huawei P8 lite Smartphone, Display 5.0" IPS, Dual Sim, Processore Octa-Core, Memoria 16 GB, Fotocamera 13 MP, Android 5.0, Bianco', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]']
#
#  matteo ['Asus ZenFone 3 Smartphone, Memoria Interna da 64 GB, Dual-SIM, Bianco [Italia]', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Nero [Italia]", 'Huawei P8 lite Smartphone, Display 5.0" IPS, Dual Sim, Processore Octa-Core, Memoria 16 GB, Fotocamera 13 MP, Android 5.0, Bianco', 'Samsung Galaxy S7 Smartphone, 32 GB, Nero', 'Alcatel One Touch 20-04G Telefono Cellulare, Nero']
#
#  javier ['Lenovo Moto G4 Play - Smartphone de 5 (4G, RAM de 2 GB, memoria interna de 16 GB, cámara de 8 MP, Android 6), blanco', 'Lenovo Moto G4 Play - Smartphone de 5 (4G, RAM de 2 GB, memoria interna de 16 GB, cámara de 8 MP, Android 6), blanco', 'Lenovo Moto G4 Play - Smartphone de 5 (4G, RAM de 2 GB, memoria interna de 16 GB, cámara de 8 MP, Android 6), blanco', 'Honor 6 - Smartphone libre (pantalla de 5", 16GB, 3 GB de RAM, cámara trasera de 13 MP y delantera de 5 MP, Android OS, v4.4.2 KitKat, LTE) blanco', 'BQ Aquaris X5 - Smartphone de 5" (WiFi, 2 GB de RAM, memoria interna de 16 GB, cámara 13 MP, Android 5.1) negro y gris antracito - Reacondicionado oficial']
#
#  ирина ['Samsung Galaxy S7 edge', 'Apple iPhone 5s 16GB (серебристый)', 'Samsung Galaxy A5 (2016)', 'Apple iPhone 5s 16GB (серый космос)', 'Sony Xperia L (черный)']
#
#  jack ['Samsung Galaxy S7 Edge zwart / 32 GB', 'Lenovo Motorola Moto G 4G 3 Generazione Smartphone, Display 5", Fotocamera 13 MP, Memoria 16 GB, Android 6 Lollipop, Nero [Italia]', 'Huawei P8lite zwart / 16 GB', 'Huawei Y6 Smartphone, Display 5.0" HD, IPS, 2 GB RAM, 8 GB Memoria Interna, Dual SIM, Fotocamera 8 MP, Android 5.1, Nero', 'APPLE iPhone 7 - Silver, 128 GB']
#
#  client d'amazon ['Honor 8 Smartphone débloqué 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc Nacré', 'Honor 8 Smartphone débloqué 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc Nacré', 'Honor 8 Smartphone débloqué 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc Nacré', 'Honor 8 Smartphone débloqué 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc Nacré', 'Honor 8 Smartphone débloqué 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc Nacré']
#
#  сергей ['Apple iPhone 5s 16GB (серый космос)', 'Apple iPhone 5s 16GB (серый космос)', 'Samsung Galaxy A5 (2016)', 'Sony Xperia Z1 Compact (белый)', 'Samsung Galaxy S7 edge']
#
#  максим ['Apple iPhone 5s 16GB (серебристый)', 'Apple iPhone 5s 16GB (серебристый)', 'Apple iPhone 5s 16GB (серебристый)', 'Apple iPhone 5s 16GB (серебристый)', 'Apple iPhone 5s 16GB (серый космос)']
#
#  jenny ['Huawei P8lite zwart / 16 GB', 'SAMSUNG Galaxy A3 (2017) - 16 GB, Black', 'Huawei P8 Champagne / 16 GB - Overzicht', 'Alcatel One Touch 20-04G Telefono Cellulare, Nero']
#
#  marco ['Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', 'Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', 'Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Nero [Italia]", 'Huawei P8 lite Smartphone, Display 5.0" IPS, Dual Sim, Processore Octa-Core, Memoria 16 GB, Fotocamera 13 MP, Android 5.0, Bianco']
#
#  sandra ['Samsung Galaxy S7 goud, roze / 32 GB', 'Samsung Galaxy J5 Smartphone (5 Zoll (12,7 cm) Touch-Display, 8 GB Speicher, Android 5.1) gold', 'Honor 7 Smartphone 4G, Display Full HD 5.2 Pollici, Processore Kirin 935 Octa Core 2.2 GHz, 16 GB Memoria Interna, 3 GB RAM, Fotocamera 20 MP, Argento', 'Smartphone Samsung Galaxy S4 Mini GT-I9192', 'Samsung E1200 Telefono Cellulare, Nero [Italia]']
#
#  barbara ["Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Nero [Italia]", 'Huawei P9 Lite Smartphone, LTE, Display 5,2” FHD, IPS, Processore Kirin 650, 3 GB RAM, Fotocamera 13 MP, Nero, (Marchio TIM) [Versione Italia]', 'Lenovo Motorola Moto G XT1541 3a Generazione Smartphone, 5-Inch, 4G/LTE, Fotocamera 13 MP, 16 GB, 2 GB RAM, Bianco', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", '
lenovo Moto G4 - Smartphone libre Android (5.5'', Full HD, 4G, 13 MP, 2 GB de RAM, 16 GB), color blanco", 'Huawei P8 Lite-AM08 - Pack Smartphone Huawei P8 Lite negro con Altavoz portátil AM08 Gold (2 GB de RAM, 16 GB de memoria interna, cámara 13 Mpxs/8Mpx), color negro']
#
#  liz ['Motorola Moto X Pure Edition Unlocked Smartphone, 64 GB Black XT1575, 5.7" Quad HD display, 21 MP Camera, Quad-core 1.8GHz', 'MICROSOFT Lumia 650 - 16 GB, Black']
#
#  ann ['MICROSOFT Lumia 650 - 16 GB, Black']
#
#  marie ['Nokia Lumia 520 GSM Unlock 3G Phone, 4-Inch Touch Screen, 5MP 720P Camera, Windows Phone (Black)']
#
#  alberto ['Lenovo Motorola Moto G Smartphone, Display HD 4,5", Processore Qualcomm, Memoria 8 GB, MicroSIM, Android 4.4 OS, Fotocamera da 5 MP, Nero [Germania]', 'LG Nexus 5 Smartphone, memoria 16GB, Android 4.4, Nero [Italia]', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Nero [Italia]", 'Asus ZenFone 2 Laser 5.5" Smartphone, 16 GB, Dual SIM, Nero [Italia]']
#
#  giuseppe ['Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", 'Samsung Galaxy A5 2016 Smartphone LTE, 16GB, Nero', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]']
#
#  diego ['Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'Honor 7 - Smartphone libre de 5.2" (4G, WiFi, Bluetooth, Dual Nano SIM, HiSilicon Kirin 935, 64 bit Super 8+1 Core, 2.2 GHz, 3 GB de RAM, 16 GB ROM, cámara de 20 MP/8 MP, Android 5.0 con EMUI 3.1), color gris', 'Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', 'Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', 'Lenovo Motorola Moto E Smartphone, Display 4.3 pollici qHD, Processore Qualcomm Dual-Core 1.2GHz, Memoria 4GB, 1GB RAM, Fotocamera 5MP, Android 4.4.2 KitKat, Bluetooth, WiFi, Bianco [Spagna]']
#
#  amanda ['Smartphone Apple iPhone 6 16GB', 'Motorola Nexus 6 Unlocked Smartphone, 32 GB, U. S. Warranty - Midnight Blue', 'MICROSOFT Lumia 650 - 16 GB, Black', 'Samsung Galaxy Note 3/S5 USB 3.0 5-Feet Data Cable, Non-Retail Packaging']
#
#  daniel ['LG Dare', 'Samsung Galaxy S7 goud, roze / 32 GB', 'Huawei Nexus 6P unlocked smartphone, 32GB Gold (US Warranty)', 'Honor 6 - Smartphone libre (pantalla de 5", 16GB, 3 GB de RAM, cámara trasera de 13 MP y delantera de 5 MP, Android OS, v4.4.2 KitKat, LTE) blanco', 'Smartphone Samsung Galaxy Gran Prime TV SM-G530']
#
#  andrew ['APPLE iPhone 6s Plus - 128 GB, Rose Gold', 'APPLE iPhone 6s Plus - 128 GB, Rose Gold', 'HUAWEI P9 Lite - 16 GB, Black', 'HUAWEI P9 Lite - 16 GB, Black', 'HUAWEI P9 Lite - 16 GB, Black']
#
#  peter ['Samsung Galaxy S7 Edge zwart / 32 GB', 'Samsung Galaxy S7 Edge wit / 32 GB', 'Samsung Galaxy S7 Edge wit / 32 GB', 'APPLE iPhone 7 - Silver, 32 GB', 'Huawei P8 Champagne / 16 GB - Overzicht']
#
#  guido ['Huawei P9 Lite Smartphone, LTE, Display 5,2” FHD, IPS, Processore Kirin 650, 3 GB RAM, Fotocamera 13 MP, Nero, (Marchio TIM) [Versione Italia]', 'Huawei P8lite zwart / 16 GB', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", 'Huawei P8 grijs / 16 GB', 'Huawei P8 lite Smartphone, Display 5.0" IPS, Dual Sim, Processore Octa-Core, Memoria 16 GB, Fotocamera 13 MP, Android 5.0, Bianco']
#
#  walter ['Honor 4X Smartphone 4G, Display 5.5 Pollici, Processore 64-bit Octa-Core Kirin 620, Fotocamera 13 MP, Memoria 8 GB, Android 4.4, Nero', 'Oukitel U7 Plus - 5,5 pollici HD Android 6.0 4G smartphone quad-core a 1,3 GHz 2 GB di RAM 16 GB ROM scanner di impronte digitali GPS Dual SIM 13 MP - Grigio', 'HOMTOM HT7 3G WCDMA 5.5 "IPS smartphone Android 5.1 OS Quad Core MTK6580A', 'LG Nexus 5X Unlocked Smartphone - White 32GB (U.S. Warranty)']
#
', 'Asus ZenFone 3 Smartphone, Memoria Interna da 64 GB, Dual-SIM, Bianco [Italia]', 'LG Nexus 5 Smartphone, memoria 16GB, Android 4.4, Nero [Italia]']
#
#  jc ["Lenovo Moto G4 - Smartphone libre Android (5.5'', Full HD, 4G, 13 MP, 2 GB de RAM, 16 GB), color blanco"]
#
#  wolfgang ['Motorola Moto G 3. Generation Smartphone (12,7 cm (5 Zoll ) Touchscreen-Display, 16 GB Speicher, Android 5.1.1...', 'Lenovo Motorola Moto G Smartphone (11,4 cm (4,5 Zoll) HD-Display, 5 Megapixel Kamera, 1,2 GHz Quad-Core-Prozessor, 16 GB interner Speicher, Android 4.3 OS) schwarz', 'Cubot Note S Smartphone ohne Vertrag (5.5 Zoll (13,9 cm) HD Touch-Display mit 4150mAh Akku, 2GB Ram/16GB interner Speicher, Android 6.0, Dual-SIM, 5MP/8MP dual Kamera, Quad-Core Prozessor, IPS 2.5D gebogener Bildschirm) für T-mobile, Vodafone, o2-de, E-Plus usw', 'Samsung Galaxy S III i9300 Smartphone 16 GB (12,2 cm (4,8 Zoll) HD Super-AMOLED-Touchscreen, 8 Megapixel Kamera, Micro-SIM, Android 4.0) schwarz']
#
#  виктория ['Samsung S5830 Galaxy Ace', 'Sony Xperia C (фиолетовый)', 'Samsung Galaxy S4 mini Duos GT-I9192 (белый)', 'Samsung I8190 Galaxy S III mini 8GB (белый)', 'Sony Xperia M (фиолетовый)']
#
#  mike ['Sim Free Motorola Moto G 4th Generation Mobile Phone - Black', 'Sim Free Motorola Moto G 4th Generation Mobile Phone - Black', 'LG Dare', 'Samsung Galaxy S7 Edge goud / 32 GB', 'Samsung Galaxy A5 (2016) Smartphone (5,2 Zoll (13,22 cm) Touch-Display, 16 GB Speicher, Android 5.1) pink-gold']
#
#  user ['Lenovo Vibe K5 (Grey)']
#
#  chris ['APPLE iPhone 6s Plus - 128 GB, Rose Gold', 'HUAWEI P9 Lite - 16 GB, Black', 'Samsung Galaxy S7 zwart / 32 GB', 'Huawei Honor 5X Unlocked Smartphone, 16GB Dark Grey (US Warranty)', 'APPLE iPhone 7 Plus - Gold, 32 GB']
#
#  patrick ["Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", 'Honor 7 Smartphone débloqué 4G (Ecran: 5,2 pouces - 16 Go - Double Nano SIM - Android 5.0 Lollipop) Argent/Blanc', 'APPLE iPhone 7 - Silver, 32 GB', 'AICEK Coque Samsung Galaxy A3 2016, AICEK Etui Silicone Gel Samsung Galaxy A3 2016 (A310F) Housse Antichoc Samsung A3 Transparente Souple Coque De Protection Pour Samsung Galaxy A3 2016 (4,7 pouces)', 'Huawei P8lite zwart / 16 GB']
#
#  rafa ['Motorola Moto G (3ª Generación) + Carcasa Oficial color turquesa - Smartphone libre Android 6 (4G, pantalla 5", cámara 13 Mp, 16 GB, Quad Core 1.4 GHz, 2 GB de RAM), negro', "Lenovo Moto G4 - Smartphone libre Android (5.5'', Full HD, 4G, 13 MP, 2 GB de RAM, 16 GB), color blanco"]
#
#  praveen ['Honor 6X (Silver, 32GB)', 'OnePlus 3 (Soft Gold, 64 GB)', 'Lenovo Vibe X3 (White, 32GB)', 'OnePlus One (Sandstone Black, 64GB)', 'OnePlus X (Onyx, 16GB)']
#
#  ???????????? ['Sony Xperia V (?????�??????)', 'Sony Xperia V (?�????????????)', 'Sony Xperia V (?�????????????)', 'HTC Desire SV T326e Black 4710937389005 UACRF']
#
#  dinesh ['Samsung Galaxy S7 goud, roze / 32 GB', 'Apple iPhone 6s (Rose Gold, 16GB)', 'Lenovo Vibe K4 Note (White,16GB)', 'Lenovo Vibe K4 Note (Black, 16GB)', 'Lenovo Vibe K5 (Gold, VoLTE update)']
#
#  ruben ['Samsung Galaxy S7 Edge zwart / 32 GB', 'ZTE Axon 7 Unlocked Smartphone,64GB Ion Gold (US Warranty)']
#
#  rahul ['Samsung Galaxy J3 (8GB)', 'OnePlus 3T (Gunmetal, 6GB RAM + 128GB memory)', 'OnePlus 3 (Graphite, 64 GB)', 'Samsung Guru GT-E1200 (Indigo Blue)', 'Honor 6X (Silver, 32GB)']
#
#  dan ['Honor 7 Smartphone débloqué 4G (Ecran: 5,2 pouces - 16 Go - Double Nano SIM - Android 5.0 Lollipop) Gris/Noir', 'Huawei P8 lite Smartphone, Display 5.0" IPS, Dual Sim, Processore Octa-Core, Memoria 16 GB, Fotocamera 13 MP, Android 5.0, Bianco', 'Apple iPhone 5c GSM Unlocked Cellphone, 16GB, Pink', 'Apple iPhone 5 A1428 Factory Unlocked Cellphone, 16GB, Black']
#
#  andreas ['Samsung Galaxy A5 (2016) Smartphone (5,2 Zoll (13,22 cm) Touch-Display, 16 GB Speicher, Android 5.1) pink-gold', 'Sony Xperia Z2 Smartphone (5,2 Zoll (13,2 cm) Touch-Display, 16 GB Speicher, Android 4.4) violett', 'Sony Xperia Z2 Smartphone (5,2 Zoll (13,2 cm) Touch-Display, 16 GB Speicher, Android 4.4) violett', 'Huawei P8 lite Dual-SIM Smartphone (5 Zoll (12,7 cm) Touch-Display, 16 GB Speicher, Android 5.0) weiß', 'Samsung Galaxy S4 mini Smartphone (10,9 cm (4,3 Zoll) Touch-Display, 8 GB Speicher, Android 4.2) schwarz']
#
#  sergio ['LG G2 - Smartphone libre Android (pantalla 5.2", cámara 13 Mp, 16 GB, Quad-Core 2.3 GHz, 2 GB RAM), blanco', 'LG G2 - Smartphone libre Android (pantalla 5.2", cámara 13 Mp, 16 GB, Quad-Core 2.3 GHz, 2 GB RAM), blanco', 'Lenovo Motorola Moto G Smartphone, Display HD 4,5", Processore Qualcomm, Memoria 8 GB, MicroSIM, Android 4.4 OS, Fotocamera da 5 MP, Nero [Germania]', 'Samsung Galaxy A5 2016 Smartphone LTE, 16GB, Nero', 'Asus ZenFone 2 Laser 5.5" Smartphone, 16 GB, Dual SIM, Nero [Italia]']
#
#  francesca ['Lenovo Motorola Moto G Smartphone, Display HD 4,5", Processore Qualcomm, Memoria 8 GB, MicroSIM, Android 4.4 OS, Fotocamera da 5 MP, Nero [Germania]', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'Huawei Y6 Smartphone, Display 5.0" HD, IPS, 2 GB RAM, 8 GB Memoria Interna, Dual SIM, Fotocamera 8 MP, Android 5.1, Nero']
#
#  anita ['Huawei P8lite zwart / 16 GB', 'Huawei P8lite zwart / 16 GB', 'Samsung Galaxy S7 Edge wit / 32 GB', 'Samsung Galaxy S7 Edge wit / 32 GB', 'APPLE iPhone 7 - Silver, 32 GB']
#
#  jonas ['Smartphone Apple iPhone 6 16GB', 'Samsung Galaxy S7 Edge goud / 32 GB']
#
#  nathalie ['Samsung Galaxy S7 zwart / 32 GB']
#
#  jennifer ['SAMSUNG Galaxy A3 (2017) - 16 GB, Black', 'Huawei P8 Champagne / 16 GB - Overzicht', 'APPLE iPhone 7 - Silver, 32 GB', 'Tracfone Motorola Moto E Android Prepaid Phone with Triple Minutes (Tracfone)', 'BLU Studio 6.0 HD - Factory Unlocked ("Black")']
#
#  claudio ["Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", 'LG D802 G2 Smartphone, 16 GB, Nero [Italia]', 'Asus ZenFone 3 Smartphone, Memoria Interna da 64 GB, Dual-SIM, Bianco [Italia]', 'Asus ZenFone 3 Smartphone, Memoria Interna da 64 GB, Dual-SIM, Bianco [Italia]', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Nero [Italia]"]
#
#  a ['Samsung G920 Galaxy S6 Smartphone, 32 GB, Nero [Italia]', 'HTC Desire', 'OnePlus X (Limited Edition Ceramic)', 'LG G4 Unlocked Smartphone with 32GB Internal Memory, 16 MP Camera and 5.5-Inch IPS Quantum Display for GSM and CDMA, US Warranty (Black Leather)']
#
#  андрей ['Sony Xperia Z (белый)', 'Samsung Galaxy S7', 'Apple iPhone 5s 16GB (серебристый)', 'LG Optimus L7 P705 Black', 'Sony Xperia Z (черный)']
#
#  lauren ['Huawei P8 Lite goud, wit / 16 GB', 'Tracfone Motorola Moto E Android Prepaid Phone with Triple Minutes (Tracfone)']
#
#  tom ['Sim Free Motorola Moto G 4th Generation Mobile Phone - Black', 'Apple iPhone 5s 16GB (серебристый)', 'Samsung Galaxy S7 goud, roze / 32 GB', 'Samsung Galaxy S7 zwart / 32 GB', 'Motorola Moto G 3. Generation Smartphone (12,7 cm (5 Zoll ) Touchscreen-Display, 16 GB Speicher, Android 5.1.1...']
#
#  antoine ["Sony Mobile Station d'accueil DK48 - s'adapte Xperia Z3, Xperia Z3 Compact", 'Samsung Galaxy A5 2016 Smartphone débloqué 4G (Ecran: 5,2 pouces - 16 Go - Simple Nano-SIM - Android 5.1 Lollipop) Or (Import Allemagne)']
#
#  simon ['Nokia Microsoft Lumia 640 Windows 8.1 Phone, 4G LTE 5 Inch Display 1GB RAM 8GB ROM (AT&T Go Phone No Annual Contract)']
#
#  ravi ['Samsung Galaxy J3 (8GB)', 'OnePlus 3T (Soft Gold, 6GB RAM + 64GB memory)', 'OnePlus X (Onyx, 16GB)', 'Samsung Galaxy J7 SM-J700F (Black, 16GB)', 'Lenovo Vibe K4 Note (Black, 16GB)']
#
#  jason ['Samsung Galaxy S7 Edge Factory Unlocked Phone 32 GB International Version (Black Onyx)', 'Samsung Galaxy Grand Prime Dual Sim Factory Unlocked Phone - Retail Packaging - Gold(International Version)', 'Apple iPhone 5C Factory Unlocked Cellphone, 8GB, White', 'Sprint LG Volt White (Sprint Prepaid)', 'YU Yuphoria YU5010A (Black+Silver)']
#
#  артём ['Apple iPhone 5s 16GB (серый космос)', 'Samsung Galaxy S7', 'Sony Xperia Z (белый)', 'Sony Xperia Z (черный)', 'Samsung Galaxy S4 mini Duos GT-I9192 (черный)']
#
#  владимир ['Samsung Galaxy S7 edge', 'Samsung Galaxy Note5', 'Samsung Galaxy S6', 'Apple iPhone 5s 16GB (серый космос)', 'Apple iPhone 5s 16GB (серый космос)']
#
#  ben ['Samsung Galaxy S7 zwart / 32 GB', 'APPLE iPhone 7 - Silver, 128 GB']
#
#  michael ['Motorola Moto G 4G SIM-Free Smartphone - Black (8GB) - Discontinued by manufacturer', 'SAMSUNG Galaxy A3 (2017) - 16 GB, Black', 'SAMSUNG Galaxy A3 (2017) - 16 GB, Black', 'APPLE iPhone 6s Plus - 128 GB, Rose Gold', 'Samsung Galaxy A5 2016 Smartphone LTE, 16GB, Nero']
#
#  francesco ["Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]"]
#
#  monique ['Smartphone Apple iPhone 6 16GB', 'Samsung Galaxy S7 goud, roze / 32 GB', 'Samsung Galaxy S7 zwart / 32 GB', 'Huawei P8lite zwart / 16 GB', 'Huawei P8lite zwart / 16 GB']
#
#  manuel ['Honor 7 - Smartphone libre de 5.2" (4G, WiFi, Bluetooth, Dual Nano SIM, HiSilicon Kirin 935, 64 bit Super 8+1 Core, 2.2 GHz, 3 GB de RAM, 16 GB ROM, cámara de 20 MP/8 MP, Android 5.0 con EMUI 3.1), color gris', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", 'Huawei Ascend P8 Smartphone, Display 5.2" FHD, Memoria RAM da 3 GB, Processore HiSilicon Kirin 930 Octa-Core, Fotocamera Principale 13 MP, Grigio', 'Alcatel Onetouch 2004G - Móvil libre (pantalla 2.4", 512 MB RAM, teclas grandes), blanco', 'Sony Xperia P - Smartphone libre (pantalla t??ctil de 4" 540 x 960, c??mara 8 Mp, 16 GB, 2 procesadores de 1 GHz, 1 GB de RAM, S.O. Android 2.3), negro']
#
#  надежда ['Samsung Galaxy A5', 'Sony Xperia Z1 Compact (белый)', 'Apple iPhone 5s 16GB (серебристый)', 'Samsung N7100 Galaxy Note II 16GB (белый)', 'Samsung I8190 Galaxy S III mini 8GB (белый)']
#
#  fabio ['Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', 'Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', 'Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', 'Samsung Galaxy A5 2016 Smartphone LTE, 16GB, Nero']
#
#  mary ['SAMSUNG Galaxy A3 (2017) - 16 GB, Black', 'Samsung Galaxy S6 Smartphone (5,1 Zoll (12,9 cm) Touch-Display, 128 GB Speicher, Android 5.0) gold (Nur für Europäische SIM-Karte)', 'Apple iPhone 5C 16GB - sbloccato - blu / ciano', 'Samsung Galaxy Note, i717 16GB Unlocked GSM 4G LTE 8MP Camera Smartphone with S Pen Stylus - White']
#
#  customer ['OnePlus 3T (Soft Gold, 6GB RAM + 64GB memory)', 'ZTE Axon 7 Unlocked Smartphone,64GB Ion Gold (US Warranty)', 'Samsung Galaxy Grand Prime Dual Sim Factory Unlocked Phone - Retail Packaging - Gold(International Version)', 'LG G2 D800 GSM 4G LTE Unlocked Smartphone with 13MP Camera, 32GB, Black', 'Apple iPhone 6s (Rose Gold, 16GB)']
#
#  carlo ['Asus ZenFone 3 Smartphone, Memoria Interna da 64 GB, Dual-SIM, Bianco [Italia]', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Nero [Italia]", 'Samsung G935 Galaxy S7 Edge Smartphone da 32GB, Argento [Italia]', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'Huawei Ascend P6 Smartphone, 8 GB, Fotocamera 8 MP, Display 4.7 Pollici HD, Wi-Fi, Rosa']
#
# ...
#
#  javi ['Asus ZenFone 3 Smartphone, Memoria Interna da 64 GB, Dual-SIM, Bianco [Italia]', 'Alcatel Onetouch 2004G - Móvil libre (pantalla 2.4", 512 MB RAM, teclas grandes), blanco', 'Sony Xperia P - Smartphone libre (pantalla t??ctil de 4" 540 x 960, c??mara 8 Mp, 16 GB, 2 procesadores de 1 GHz, 1 GB de RAM, S.O. Android 2.3), negro', "Lenovo Moto G4 - Smartphone libre Android (5.5'', Full HD, 4G, 13 MP, 2 GB de RAM, 16 GB), color blanco", 'Samsung Galaxy Ace S5830 Smartphone (8,9 cm (3,5 Zoll) Display, Touchscreen, Android OS, 5 Megapixel Kamera) weiß']
#
#  rakesh ['OnePlus 3 (Graphite, 64 GB)', 'OnePlus 3 (Graphite, 64 GB)', 'OnePlus 3 (Soft Gold, 64 GB)', 'Microsoft Lumia 640 XL (Dual SIM, Cyan)', 'Lenovo Vibe K4 Note (White,16GB)']
#
#  vicente ['Lenovo Moto G4 Play - Smartphone de 5 (4G, RAM de 2 GB, memoria interna de 16 GB, cámara de 8 MP, Android 6), blanco', 'Samsung Galaxy S6']
#
#  ?????�?????? ['Sony Xperia V (?????�??????)', 'Sony Xperia V (?�????????????)', 'Sony Xperia V (?�????????????)', 'Sony Xperia V (?�????????????)', 'Sony Xperia V (?�????????????)']
#
#  roland ['Lenovo Moto G4 Smartphone (14 cm (5,5 Zoll), 16GB, Android) weiß', 'Huawei P8lite zwart / 16 GB', 'Samsung Galaxy S4 mini Smartphone (10,9 cm (4,3 Zoll) Touch-Display, 8 GB Speicher, Android 4.2) schwarz', 'Samsung Galaxy S III i9300 Smartphone 16 GB (12,2 cm (4,8 Zoll) HD Super-AMOLED-Touchscreen, 8 Megapixel Kamera, Micro-SIM, Android 4.0) schwarz']
#
#  veronica ['Nokia Microsoft Lumia 640 Windows 8.1 Phone, 4G LTE 5 Inch Display 1GB RAM 8GB ROM (AT&T Go Phone No Annual Contract)', 'Sprint LG Volt White (Sprint Prepaid)']
#
#  gianni ['LG G4 Smartphone Display IPS 5.5" QHD, Fotocamera 16 MP, Memoria Interna 32 GB, 3 GB RAM, Colore Marrone', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.2 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Nero [Italia]']
#
#  mimi ['Samsung Galaxy S5 Smartphone (5,1 Zoll (12,9 cm) Touch-Display, 16 GB Speicher, Android 4.4) electric blue']
#
#  anand ['Apple iPhone 6 (Space Grey, 16GB)', 'OnePlus 3 (Graphite, 64 GB)', 'Lenovo Vibe K4 Note (White,16GB)', 'Motorola Moto G, 4th Gen (White, 16GB) - Android 7.0 Nougat Update Available Now', 'Motorola Moto G Turbo (White, 16GB)']
#
#  greg ['Samsung Galaxy Centura Android Prepaid Phone (TracFone)']
#
#  angie ['Sony Xperia Z3 Compact Smartphone (11,7 cm (4,6 Zoll) HD-TRILUMINOS-Display, 2,5 GHz-Quad-Core-Prozessor, 20,7 Megapixel-Kamera, Android 4.4) meergrün']
#
#  stefania ['Samsung Galaxy J5 Smartphone, Oro [Italia]', 'Asus ZenFone 2 Laser Smartphone da 32 GB, Dual SIM, Bianco [Italia]', 'Asus ZenFone Go 5" Smartphone, 8 GB, Dual SIM, Bianco [Italia]']
#
#  isabelle ['Huawei P8 Lite goud, wit / 16 GB']
#
#  enrique ['Samsung Galaxy S III mini (I8190) - Smartphone libre Android (pantalla 4", cámara 5 Mp, 8 GB, Dual-Core 1 GHz, 1 GB RAM), azul']
#
#  mattia ['Asus ZE551ML-2A760WW Smartphone ZenFone 2 Deluxe, 5.5", 4 GB RAM, 64 GB, Intel Quad-Core Z3580, Dual SIM, Illusion Purple', 'Lenovo Motorola Moto G 4G (2 Generazione) Smartphone, Display 5 Pollici, LTE, Fotocamera 8 MP, Memoria 8 GB, Android 5 Lollipop, Nero [Italia]']
#
#  luciano ['Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', "Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", 'Alcatel One Touch 20-04G Telefono Cellulare, Nero']
#
#  jordan ['LG Dare', 'APPLE iPhone 7 Plus - Gold, 32 GB', 'Motorola Nexus 6 Unlocked Smartphone, 32 GB, U. S. Warranty - Midnight Blue', 'LG RUMOR']
#
#  bart ['Huawei P8 Lite goud, wit / 16 GB', 'Huawei P8 grijs / 16 GB', 'Huawei P8lite zwart / 16 GB']
#
#  wendy ['HUAWEI P9 Lite - 16 GB, Black', 'Huawei P8 grijs / 16 GB', 'Apple iPhone 5C 8GB Factory Unlocked GSM Cell Phone - Blue']
#
#  steph ['Honor 7 Smartphone 4G, Display Full HD 5.2 Pollici, Processore Kirin 935 Octa Core 2.2 GHz, 16 GB Memoria Interna, 3 GB RAM, Fotocamera 20 MP, Argento', 'APPLE iPhone 7 - Silver, 128 GB', 'Apple iPhone 5 16GB Verizon Wireless CDMA 4G LTE Cell Phone - White']
#
#  rebecca ['SAMSUNG Galaxy A3 (2017) - 16 GB, Black', 'Apple iPhone 4S AT&T Cellphone, 16GB, Black']
#
#  ???????????????? ['HTC Desire SV T326e Black 4710937389005 UACRF', 'Sony Xperia V (?�????????????)', 'Sony Xperia V (?�????????????)']
#
#  steve ['Lenovo Motorola Moto G LTE Smartphone, Display 4.5", Fotocamera 5 MP, Memoria 8 GB, Quad-Core 1.2 GHz, 1 GB RAM, Micro SD, Android 4.4.3, Bianco [Italia]', 'LG Dare', 'Huawei Nexus 6P unlocked smartphone, 32GB Gold (US Warranty)', 'Motorola Moto X Pure Edition Unlocked Smartphone, 64 GB Black XT1575, 5.7" Quad HD display, 21 MP Camera, Quad-core 1.8GHz', 'Motorola Moto X Pure Edition Unlocked Smartphone, 64 GB Black XT1575, 5.7" Quad HD display, 21 MP Camera, Quad-core 1.8GHz']
#
#  michelle ['Samsung Galaxy S7 goud, roze / 32 GB', 'APPLE iPhone 7 - Silver, 128 GB', 'Apple iPhone 5c GSM Unlocked Cellphone, 16GB, Pink']
#
#  r ['Sprint LG Volt White (Sprint Prepaid)']
#
#  nicole ['Samsung Galaxy S7 Edge zwart / 32 GB', 'LG G2 D800 GSM 4G LTE Unlocked Smartphone with 13MP Camera, 32GB, Black', 'Lenovo Motorola Moto G 4G (2 Generazione) Smartphone, Display 5 Pollici, LTE, Fotocamera 8 MP, Memoria 8 GB, Android 5 Lollipop, Nero [Italia]', 'Sprint LG Volt White (Sprint Prepaid)']
#
#  melanie ['Samsung S5830 Galaxy Ace', 'Cubot Note S Smartphone ohne Vertrag (5.5 Zoll (13,9 cm) HD Touch-Display mit 4150mAh Akku, 2GB Ram/16GB interner Speicher, Android 6.0, Dual-SIM, 5MP/8MP dual Kamera, Quad-Core Prozessor, IPS 2.5D gebogener Bildschirm) für T-mobile, Vodafone, o2-de, E-Plus usw', 'Samsung Galaxy Note, i717 16GB Unlocked GSM 4G LTE 8MP Camera Smartphone with S Pen Stylus - White']
#
#  kelly ['APPLE iPhone 7 Plus - Gold, 32 GB', 'Celular Motorola EX115']
#
#  annie ['Huawei P8 Champagne / 16 GB - Overzicht', 'Huawei P8 Lite goud, wit / 16 GB']
#
#  olga ['Microsoft Nokia Lumia 630 Single-SIM Smartphone (4,5 Zoll (11,4 cm) Touch-Display, 8 GB Speicher, Windows 8.1) gelb']
#
#  sandro ["Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]"]
#
#  gustavo ['Smartphone Apple iPhone 6 16GB', 'Smartphone Motorola Moto X 2ª Geração XT1097 32 GB', 'Smartphone Samsung Galaxy S7 Edge SM-G935 32GB']
#
#  theo ['Huawei P8lite zwart / 16 GB', 'Huawei P8 Lite goud, wit / 16 GB']
#
#  albert ['Huawei P8 grijs / 16 GB', 'Huawei P9 lite - Smartphone libre Android (pantalla 5.2", cámara 13 MP, 16 GB, Octa-Core 2 GHz, 3 GB RAM), oro', 'MICROSOFT Lumia 650 - 16 GB, Black']
#
#  jerry ['Samsung Galaxy Centura Android Prepaid Phone (TracFone)']
#
#  andres ['Honor 6 - Smartphone libre (pantalla de 5", 16GB, 3 GB de RAM, cámara trasera de 13 MP y delantera de 5 MP, Android OS, v4.4.2 KitKat, LTE) blanco', 'Samsung Galaxy S4 (I9505) - Smartphone libre Android (pantalla táctil de 4.99", cámara 13 Mp, 16 GB, Quad-Core 1.9 GHz, 2 GB RAM, LTE), Blanco (Versión Europea)']
#
#  will ['Motorola Moto G 3rd Generation LTE UK SIM-Free Smartphone - White', 'Huawei P8lite zwart / 16 GB', 'LG Nexus 5X Unlocked Smartphone - White 32GB (U.S. Warranty)', 'Apple iPhone 6 16GB Factory Unlocked GSM 4G LTE Internal Smartphone - Space Gray']
#
#  anthony ['Samsung Galaxy A5', 'APPLE iPhone 7 - Silver, 128 GB', 'APPLE iPhone 7 - Silver, 128 GB', 'Apple iPhone 5 A1428 Factory Unlocked Cellphone, 16GB, Black', 'MICROSOFT Lumia 650 - 16 GB, Black']
#
#  kate ['Vodafone Smart First 6 Pay As You Go Handset Smartphone - Black', 'Apple iPhone 5c 32GB (Green) - Verizon Wireless']
#
#  sven ['Huawei P8 Lite goud, wit / 16 GB']
#
#  petra ['Samsung Galaxy S7 Edge wit / 32 GB']
#
#  micha ['Honor 7 Smartphone (13,2 cm (5,2 Zoll) Touchscreen, 16GB interner Speicher, Android OS) grau']
#
#  adrian ['APPLE iPhone 6s Plus - 128 GB, Rose Gold', 'Samsung Galaxy Note, i717 16GB Unlocked GSM 4G LTE 8MP Camera Smartphone with S Pen Stylus - White']
#
#  fernando ['Honor 6 - Smartphone libre (pantalla de 5", 16GB, 3 GB de RAM, cámara trasera de 13 MP y delantera de 5 MP, Android OS, v4.4.2 KitKat, LTE) blanco', 'Lenovo Motorola Moto E Smartphone, Display 4.3 pollici qHD, Processore Qualcomm Dual-Core 1.2GHz, Memoria 4GB, 1GB RAM, Fotocamera 5MP, Android 4.4.2 KitKat, Bluetooth, WiFi, Bianco [Spagna]', 'Smartphone Motorola Razr XT910', 'Nokia C2-06']
#
#  jeremy ['LG Dare', 'MICROSOFT Lumia 650 - 16 GB, Black']
#
#  roger ['Samsung Galaxy A3 (2016)', 'MICROSOFT Lumia 650 - 16 GB, Black', 'APPLE iPhone 7 Plus - Black, 128 GB']
#
#  t ['Apple iPhone 5C Factory Unlocked Cellphone, 8GB, White', 'Sprint LG Volt White (Sprint Prepaid)']
#
#  mandy ['Samsung Galaxy S7 Edge zwart / 32 GB', 'Huawei P8lite zwart / 16 GB', 'Huawei P8lite zwart / 16 GB', 'Samsung Galaxy S5 Smartphone (5,1 Zoll (12,9 cm) Touch-Display, 16 GB Speicher, Android 4.4) electric blue']
#
#  erica ['Huawei P8 Lite 2017 Smartphone, 16 GB, Nero']
#
#  cristiano ["Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", 'Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]', 'WIKO Fever 4G Smartphone, 16 GB, Dual SIM, Nero/Antracite']
#
#  sue ['HUAWEI P9 Lite - 16 GB, Black']
#
#  marta ['LG Nexus 5X - Smartphone de 5.2" (WiFi, DLNA, procesador Qualcomm Snapdragon 808 de 64 bits y 6 núcleos, memoria interna de 32 GB, memoria RAM 2 GB, Android Marshmallow), color negro', 'Motorola Moto G (3ª Generación) + Carcasa Oficial color turquesa - Smartphone libre Android 6 (4G, pantalla 5", cámara 13 Mp, 16 GB, Quad Core 1.4 GHz, 2 GB de RAM), negro', 'Huawei P8 Lite-AM08 - Pack Smartphone Huawei P8 Lite negro con Altavoz portátil AM08 Gold (2 GB de RAM, 16 GB de memoria interna, cámara 13 Mpxs/8Mpx), color negro']
#
#  rita ['Nokia C2-06']
#
#  kunde ['Samsung Galaxy S5 mini Smartphone (4,5 Zoll (11,4 cm) Touch-Display, 16 GB Speicher, Android 4.4) gold']
#
#  nathan ['Smartphone Apple iPhone 6 16GB', 'Smartphone LG G2 D805', 'Nokia Lumia 520 GSM Unlock 3G Phone, 4-Inch Touch Screen, 5MP 720P Camera, Windows Phone (Black)', 'Motorola Moto G 3rd Generation (Black, 8GB)']
#
#  patrizia ['Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]']
#
#  manfred ['Huawei P8 Lite goud, wit / 16 GB']
#
#  ?????????�???? ['Sony Xperia V (?????�??????)', 'Sony Xperia V (?????�??????)']
#
#  guy ['Tracfone Motorola Moto E Android Prepaid Phone with Triple Minutes (Tracfone)']
#
#  jimmy ['Huawei Honor 5X Unlocked Smartphone, 16GB Dark Grey (US Warranty)', 'Apple iPhone 6 Plus GSM Unlocked Cellphone, 64GB, Space Gray']
#
#  dirk ['Samsung Galaxy A5 (2016) Smartphone (5,2 Zoll (13,22 cm) Touch-Display, 16 GB Speicher, Android 5.1) pink-gold', 'Huawei P8 Lite wit / 16 GB', 'Huawei P8lite zwart / 16 GB', 'Huawei P8lite zwart / 16 GB', 'Sony Xperia Z2 Smartphone (5,2 Zoll (13,2 cm) Touch-Display, 16 GB Speicher, Android 4.4) violett']
#
#  g ['Honor 7 Smartphone débloqué 4G (Ecran: 5,2 pouces - 16 Go - Double Nano SIM - Android 5.0 Lollipop) Argent/Blanc']
#
#  don ['Lenovo Used Lenovo Vibe S1 (White, 32GB)']
#
#  dominique ['Samsung Galaxy S7 zwart / 32 GB']
#
#  carol ['Apple iPhone 5 A1428 Factory Unlocked Cellphone, 16GB, Black']
#
#  amazon kundenrezensionen ['Sony Xperia Z2 Smartphone (5,2 Zoll (13,2 cm) Touch-Display, 16 GB Speicher, Android 4.4) violett']
#
#  christoph ['Samsung Galaxy A3 Smartphone (4,5 Zoll (11,4 cm) Touch-Display, 16 GB Speicher, Android 4.4) champagne-gold']
#
#  stephan ['Samsung Galaxy S III i9300 Smartphone 16 GB (12,2 cm (4,8 Zoll) HD Super-AMOLED-Touchscreen, 8 Megapixel Kamera, Micro-SIM, Android 4.0) schwarz', 'Samsung Galaxy S5 mini Smartphone (4,5 Zoll (11,4 cm) Touch-Display, 16 GB Speicher, Android 4.4) gold']
#
#  melissa ['Samsung J320 Galaxy J3 (2016) Dual SIM 5", Quad Core, 8GB LTE, Nero [Italia]', 'Samsung Galaxy S7 Edge Factory Unlocked Phone 32 GB International Version (Black Onyx)']
#
#  anja ['Samsung Galaxy S4 mini Smartphone (10,9 cm (4,3 Zoll) Touch-Display, 8 GB Speicher, Android 4.2) schwarz']
#
#  brandon ['LG G4 Unlocked Smartphone with 32GB Internal Memory, 16 MP Camera and 5.5-Inch IPS Quantum Display for GSM and CDMA, US Warranty (Black Leather)']
#
#  dani ['Samsung Galaxy S7 Edge zwart / 32 GB']
#
#  ashley ['Nokia Lumia 520 GSM Unlock 3G Phone, 4-Inch Touch Screen, 5MP 720P Camera, Windows Phone (Black)', 'Samsung Galaxy S4 SGH-I337 Unlocked GSM Smartphone with 13 MP Camera, Touchscreen and 16 GB Storage, Black']
#
#  didier ['Samsung Galaxy J3 Smartphone débloqué 4G (Ecran: 5 Pouces - 8 Go - Micro-SIM - Android Lollipop 5.1) Noir']
#
#  jesús ['Samsung Galaxy S III mini (I8190) - Smartphone libre Android (pantalla 4", cámara 5 Mp, 8 GB, Dual-Core 1 GHz, 1 GB RAM), azul', 'Samsung Galaxy S7 edge SM-G935F 32GB 4G Pink gold - Smartphone (SIM única, Android, NanoSIM, GSM, UMTS, WCDMA, LTE)', 'Doogee X5 - Smartphone libre Android (pantalla 5", cámara 8 Mp, 8 GB, Quad-Core 1.3 GHZ, 1 GB RAM), color blanco']
#
#  jm ['Honor 8 Smartphone débloqué 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc Nacré']
#
#  santiago ['Alcatel Onetouch 2004G - Móvil libre (pantalla 2.4", 512 MB RAM, teclas grandes), blanco', 'BQ Aquaris E5 LTE - Smartphone libre Android (pantalla 5 pulgadas, cámara 13 Mp. 16 GB, Qualcomn Snapdragon 410 Quad-Core A53, 2 GB RAM), color negro']
#
#  susana ['Huawei P8 Lite-AM08 - Pack Smartphone Huawei P8 Lite negro con Altavoz portátil AM08 Gold (2 GB de RAM, 16 GB de memoria interna, cámara 13 Mpxs/8Mpx), color negro']
#
#  ???????????? ?????????????? ['HTC Desire SV T326e Black 4710937389005 UACRF']
#
#  gonzalo ['Motorola Moto G (3ª Generación) + Carcasa Oficial color turquesa - Smartphone libre Android 6 (4G, pantalla 5", cámara 13 Mp, 16 GB, Quad Core 1.4 GHz, 2 GB de RAM), negro']
#
#  ralf ['Meizu M2 Note Smartphone, 5.5" Full HD, 4G, 13MPX, Dual SIM, 16GB, Bianco [EU]']
#
#  nadine ['Nokia 5230 Navigation Edition']
#
#  jamie ['Samsung Galaxy SIII UK SIM-Free Smartphone - Pebble Blue (16GB) - Discontinued by manufacturer']
#
#  nik ['OnePlus One (Sandstone Black, 64GB)']
#
#  louis ['Lenovo Vibe K5 (Grey)']
#
#  oliver ['LG Electronics G4 Smartphone 14 cm (5,5 Zoll) (Touch-Display, 32 GB Speicher, Android 6) braune Lederversion', 'APPLE iPhone 7 Plus - Black, 128 GB']
#
#  toni ['Smartphone Asus ZenFone 3 ZE520KL', 'Samsung Galaxy Grand Prime Dual Sim Factory Unlocked Phone - Retail Packaging - Gold(International Version)']
#
#  kk ['OnePlus X (Onyx, 16GB)']
#
#  alexandre ['Smartphone LG G4 H818P']
#
#  ???????????? ???????? ['Sony Xperia V (?????�??????)']
#
#  jen ['iPhone 5S APPLE IPHONE 5S 32GB SILVER UNLOCKED']
#
#  debbie ['Apple iPhone 6 16GB Factory Unlocked GSM 4G LTE Internal Smartphone - Space Gray']
#
#  cris ['Meizu M2 Note Smartphone, 5.5" Full HD, 4G, 13MPX, Dual SIM, 16GB, Bianco [EU]']
#
#  julio ['Sony Xperia P - Smartphone libre (pantalla t??ctil de 4" 540 x 960, c??mara 8 Mp, 16 GB, 2 procesadores de 1 GHz, 1 GB de RAM, S.O. Android 2.3), negro']
#
#  client amazon ['Honor 8 Smartphone débloqué 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc Nacré']
#
#  ken ['BLU Vivo XL Smartphone - 5.5" 4G LTE - GSM Unlocked - Solid Gold']
#
#  j ['Samsung Galaxy J3 (8GB)']
#
#  aaron ['Honor 6 - Smartphone libre (pantalla de 5", 16GB, 3 GB de RAM, cámara trasera de 13 MP y delantera de 5 MP, Android OS, v4.4.2 KitKat, LTE) blanco']

# %% [markdown]
# #### 9. Try cross validation techniques to get better results.

# %% [markdown]
# ###### <font color=#B40404>Cross validation on SVD from surprise, evaluating by rmse.

# %%
# Initialise analysis dataframe
df_svd_analysis = pd.DataFrame(columns=['n_factors', 'reg_all', 'n_epochs', 'lr_all', 'test_rmse', 'mean_test_rmse'])

# Set parameters for cross validation on SVD model
parameters = {'n_factors': [20, 50, 80],
              'reg_all': [0.04, 0.06],
              'n_epochs': [10, 20, 30],
              'lr_all': [0.002, 0.005, 0.01]}

# Run multiple loops to go through all parameter
for nf in parameters['n_factors']:
    for ra in parameters['reg_all']:
        for ne in parameters['n_epochs']:
            for la in parameters['lr_all']:
                
                # Set parameters for cross validation on SVD model
                gridsvd = SVD(n_factors=nf, reg_all=ra, n_epochs=ne, lr_all=la)
                ls_rmse = cross_validate(gridsvd, data, measures=['RMSE', 'MAE'], cv=3)['test_rmse']
                df_svd_analysis = df_svd_analysis.append({'n_factors': nf, 'reg_all': ra, 'n_epochs': ne, 'lr_all': la, 
                                                  'test_rmse': ls_rmse, 'mean_test_rmse': np.mean(ls_rmse)}, ignore_index=True)

# Displaying results
df_svd_analysis
# Out:
#    n_factors  reg_all n_epochs  lr_all  \
# 0         20     0.04       10   0.002
# 1         20     0.04       10   0.005
# 2         20     0.04       10   0.010
# 3         20     0.04       20   0.002
# 4         20     0.04       20   0.005
# 5         20     0.04       20   0.010
# 6         20     0.04       30   0.002
# 7         20     0.04       30   0.005
# 8         20     0.04       30   0.010
# 9         20     0.06       10   0.002
# 10        20     0.06       10   0.005
# 11        20     0.06       10   0.010
# 12        20     0.06       20   0.002
# 13        20     0.06       20   0.005
# 14        20     0.06       20   0.010
# 15        20     0.06       30   0.002
# 16        20     0.06       30   0.005
# 17        20     0.06       30   0.010
# 18        50     0.04       10   0.002
# 19        50     0.04       10   0.005
# 20        50     0.04       10   0.010
# 21        50     0.04       20   0.002
# 22        50     0.04       20   0.005
# 23        50     0.04       20   0.010
# 24        50     0.04       30   0.002
# 25        50     0.04       30   0.005
# 26        50     0.04       30   0.010
# 27        50     0.06       10   0.002
# 28        50     0.06       10   0.005
# 29        50     0.06       10   0.010
# 30        50     0.06       20   0.002
# 31        50     0.06       20   0.005
# 32        50     0.06       20   0.010
# 33        50     0.06       30   0.002
# 34        50     0.06       30   0.005
# 35        50     0.06       30   0.010
# 36        80     0.04       10   0.002
# 37        80     0.04       10   0.005
# 38        80     0.04       10   0.010
# 39        80     0.04       20   0.002
# 40        80     0.04       20   0.005
# 41        80     0.04       20   0.010
# 42        80     0.04       30   0.002
# 43        80     0.04       30   0.005
# 44        80     0.04       30   0.010
# 45        80     0.06       10   0.002
# 46        80     0.06       10   0.005
# 47        80     0.06       10   0.010
# 48        80     0.06       20   0.002
# 49        80     0.06       20   0.005
# 50        80     0.06       20   0.010
# 51        80     0.06       30   0.002
# 52        80     0.06       30   0.005
# 53        80     0.06       30   0.010
#
#                                             test_rmse  mean_test_rmse
# 0   [2.5706896694017938, 2.579327800211746, 2.5699...        2.573336
# 1   [2.5924294588297934, 2.5702711336452335, 2.566...        2.576310
# 2   [2.589401741892979, 2.6114616536935285, 2.5750...        2.591983
# 3   [2.578473435336548, 2.554974930288214, 2.58542...        2.572959
# 4   [2.5793983454343654, 2.5926310222757505, 2.610...        2.594079
# 5   [2.666912759198316, 2.634583733850986, 2.66786...        2.656454
# 6   [2.564954084322474, 2.576475882144381, 2.57015...        2.570527
# 7   [2.614275565818265, 2.6004239487526597, 2.6069...        2.607209
# 8   [2.661292688940282, 2.679344560958338, 2.67340...        2.671349
# 9   [2.5706185037879457, 2.5778419775907278, 2.569...        2.572745
# 10  [2.577808525879396, 2.5645643152606317, 2.5769...        2.573107
# 11  [2.591390020647603, 2.609656814433253, 2.57803...        2.593026
# 12  [2.556846082877745, 2.5685085827615177, 2.5926...        2.572677
# 13  [2.6089682010985342, 2.573861361190588, 2.5871...        2.589993
# 14  [2.637122158008175, 2.632059600214354, 2.62567...        2.631618
# 15  [2.5790040965434144, 2.5798784097763523, 2.569...        2.576294
# 16  [2.6164504523341416, 2.617970168475926, 2.5862...        2.606898
# 17  [2.659557200228858, 2.6428904143331318, 2.7054...        2.669312
# 18  [2.5579944688835368, 2.567878979753161, 2.5878...        2.571244
# 19  [2.5586583020470566, 2.5829592468367224, 2.587...        2.576408
# 20  [2.607055254246205, 2.6100644649033047, 2.6295...        2.615555
# 21  [2.5575869318286224, 2.5707934434546997, 2.584...        2.570997
# 22  [2.5897525191708923, 2.6049681046543878, 2.600...        2.598536
# 23  [2.649524409780157, 2.6448954484089406, 2.6429...        2.645789
# 24  [2.586166919634183, 2.571753982654528, 2.57190...        2.576609
# 25  [2.6125977857745566, 2.6329336621057164, 2.613...        2.619654
# 26  [2.6569075125587345, 2.651231476401191, 2.6670...        2.658383
# 27  [2.5819184559002792, 2.5690950208686067, 2.580...        2.577284
# 28  [2.5819822980122638, 2.5725469712013544, 2.591...        2.582010
# 29  [2.5985950804112905, 2.609230747889142, 2.5928...        2.600239
# 30  [2.571401743567688, 2.5779702299903864, 2.5663...        2.571917
# 31  [2.593773088917345, 2.5818407160742405, 2.5856...        2.587073
# 32  [2.6312824437037476, 2.6286976534410424, 2.653...        2.637763
# 33  [2.5850668930605103, 2.5777023330173194, 2.561...        2.574771
# 34  [2.60882934232806, 2.599899471208794, 2.631175...        2.613301
# 35  [2.6629942378223648, 2.6531208141072304, 2.664...        2.660221
# 36  [2.589584304730893, 2.5563019663512434, 2.5790...        2.574965
# 37  [2.5732473201929444, 2.597542732553351, 2.5695...        2.580125
# 38  [2.601077749333379, 2.614484209593109, 2.60694...        2.607503
# 39  [2.5755619193855708, 2.567832958385848, 2.5774...        2.573599
# 40  [2.589917566362172, 2.6123405562949644, 2.6001...        2.600793
# 41  [2.656660872685993, 2.6600742828007102, 2.6386...        2.651790
# 42  [2.577444466821833, 2.582682984820262, 2.56813...        2.576086
# 43  [2.637169499336466, 2.6046562765534826, 2.6069...        2.616270
# 44  [2.6594488092524653, 2.6509038562383687, 2.680...        2.663679
# 45  [2.597991362619234, 2.5676737042090294, 2.5756...        2.580432
# 46  [2.5774794087190496, 2.57327727813056, 2.57688...        2.575881
# 47  [2.6111287642565912, 2.5961731871708147, 2.593...        2.600418
# 48  [2.586946940953818, 2.5671548354823726, 2.5663...        2.573471
# 49  [2.5986462060841307, 2.5934126901526198, 2.587...        2.593187
# 50  [2.6291052673585873, 2.6410881415068213, 2.645...        2.638491
# 51  [2.5928200850721965, 2.5693249988389217, 2.565...        2.575954
# 52  [2.589230881597062, 2.6103109998128944, 2.6142...        2.604609
# 53  [2.662254017816988, 2.6527285074481193, 2.6685...        2.661165

# %% [markdown]
# ###### <font color=#B40404>Cross validation on kNNWithMeans from surprise, evaluating by rmse. I have kept item based collaboration filtering out of the cross validation steps because it took a lot of time and provided very little gain in error.

# %%
# Initialise analysis dataframe
df_knn_analysis = pd.DataFrame(columns=['name', 'user_based', 'min_k', 'test_rmse', 'mean_test_rmse'])

# Set parameters for cross validation on kNNWithMeans model
parameters = {'name': ['MSD', 'cosine'],
              'user_based': [True]}

# Run multiple loops to go through all parameter
for nm in parameters['name']:
    for ub in parameters['user_based']:
        for k in range(380, 530, 20):
            # Set parameters for cross validation on kNNWithMeans model
            gridknn = KNNWithMeans(k=k, sim_options={'name': nm, 'user_based': ub}, verbose=False)
            ls_rmse = cross_validate(gridknn, data, measures=['RMSE'], cv=3)['test_rmse']
            df_knn_analysis = df_knn_analysis.append({'name': nm, 'user_based': ub, 'min_k': k, 
                                              'test_rmse': ls_rmse, 'mean_test_rmse': np.mean(ls_rmse)}, ignore_index=True)

# Displaying results
df_knn_analysis
# Out:
#       name user_based min_k  \
# 0      MSD       True   380
# 1      MSD       True   400
# 2      MSD       True   420
# 3      MSD       True   440
# 4      MSD       True   460
# 5      MSD       True   480
# 6      MSD       True   500
# 7      MSD       True   520
# 8   cosine       True   380
# 9   cosine       True   400
# 10  cosine       True   420
# 11  cosine       True   440
# 12  cosine       True   460
# 13  cosine       True   480
# 14  cosine       True   500
# 15  cosine       True   520
#
#                                             test_rmse  mean_test_rmse
# 0   [2.6015907592332606, 2.597817268354545, 2.5988...        2.599409
# 1   [2.5885050402345033, 2.599681944927374, 2.6178...        2.602017
# 2   [2.593713827846625, 2.5916015778490533, 2.5969...        2.594093
# 3   [2.609416961311682, 2.604160388887175, 2.59183...        2.601803
# 4   [2.6117382091657144, 2.601461201622084, 2.6047...        2.605979
# 5   [2.602441384615055, 2.605005841661893, 2.60215...        2.603200
# 6   [2.5857142654861507, 2.6094406523783893, 2.600...        2.598672
# 7   [2.600482928201366, 2.598213808178769, 2.60359...        2.600764
# 8   [2.5905326315195434, 2.5895438412591982, 2.592...        2.590699
# 9   [2.573273957483209, 2.601368855529584, 2.60776...        2.594135
# 10  [2.59377105522662, 2.587870227348199, 2.605718...        2.595787
# 11  [2.592514937251914, 2.6010425372638992, 2.5862...        2.593258
# 12  [2.598586874976904, 2.5937688957347462, 2.5895...        2.593960
# 13  [2.6127666486391146, 2.57060076702263, 2.58992...        2.591097
# 14  [2.5914326364783915, 2.598360529531043, 2.5946...        2.594813
# 15  [2.5979277756803936, 2.5922811072044034, 2.591...        2.594029

# %% [markdown]
# #### 10. In what business scenario you should use popularity based Recommendation Systems ?

# %% [markdown]
# ###### <font color=#B40404>In a scenario where there are too many cold start issues (as in we do not have much information on ratings given by users on our platform) then we should use popularity based Recommendation Systems, since that looks at popularity from a macro level and simply the most popular products are recommended. When we do not have enough information on the likes and dislikes at an user level then this would become a viable option.

# %% [markdown]
# #### 11. In what business scenario you should use CF based Recommendation Systems ?

# %% [markdown]
# ###### <font color=#B40404>This type of recommendation system makes predictions of what might interest a person based on the taste of many other users. It assumes that if person X likes item A, and person Y likes item A and item B, then person X might like item B as well.
#
# ###### <font color=#B40404>In a scenario where we already have a healthy amount of data about user's historical choices, there is a huge list of items that users cannot quickly glance through and we have the necessary technical capabilities to run Recommendation Systems, then definitely the business should use CF based Recommendation Systems, since this would improve user retention as customers would keep discovering relevant items. Not only is it useful from a ROI perspective but in a situation when customers do not purchase, we can still share relevant items with the user and improve their engagement with the business. Healthy engagement from users creates an ecosystem which would align customer needs with business objectives.
#
# ###### <font color=#B40404>The latent characteristics would also create baskets which could be used to further develop business strategies.

# %% [markdown]
# #### 12. What other possible methods can you think of which can further improve the recommendation for different users ?

# %% [markdown]
# ###### <font color=#B40404>Generally the best Recommendation systems are a hybrid of a few types of systems. In our example as well, since we have so few ratings, it would be useful for certain items or users to be recommended based on popularity based recommendation systems. The recommendation should definitely have a high proportion of collaborative filtering based results, which is our model in this example. Finally to further improve recommendations, we should create a database on the technical specs of the phones in question. We should then use the technical specs to also recommend based on content based filtering. The content based filtering could play a more prominent role when the user makes a specific search or even based on his previous choices. Furthermore we could process the extracts column and see if we can recommend items based on what has been said about a different item. So if the sentiment towards a particular item's battery life is good then a user who has given good ratings to that item would probably also like other items whose sentiments match.
#
# ###### <font color=#B40404>Lastly I want to add that our own model can be still further improved by going through all the item descriptions and user handles. There seem to be a lot of garbage values involved here, so a much detailed processing of these categorical variables should improve our own model.
